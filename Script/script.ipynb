-- %% [markdown]
-- # [dbo].[LOG_CLIENT]

-- %%
USE [DB_FundaMicro]
GO

-- %%
/****** Object:  Table [dbo].[LOG_CLIENT]    Script Date: 6/5/2025 8:08:01 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LOG_CLIENT](
	[ID_LOG_CLIENT] [int] IDENTITY(1,1) NOT NULL,
	[ID_CLIENT] [int] NOT NULL,
	[THE_USER] [varchar](50) NOT NULL,
	[CRUD_ACTION] [varchar](7) NOT NULL,
	[DATE_ACTION] [datetime] NOT NULL,
 CONSTRAINT [PK_LOG_CLIENT] PRIMARY KEY CLUSTERED 
(
	[ID_LOG_CLIENT] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[THE_CLIENT]

-- %%
/****** Object:  Table [dbo].[THE_CLIENT]    Script Date: 6/5/2025 8:08:01 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[THE_CLIENT](
	[ID_CLIENT] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [varchar](60) NOT NULL,
	[LASTNAME] [varchar](60) NOT NULL,
	[CRUD_ACTION] [varchar](7) NOT NULL,
	[USR_CRUD_ACTION] [varchar](50) NOT NULL,
	[DATE_ACTION] [datetime] NOT NULL,
 CONSTRAINT [PK_THE_CLIENT] PRIMARY KEY CLUSTERED 
(
	[ID_CLIENT] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[THE_USERS]

-- %%
/****** Object:  Table [dbo].[THE_USERS]    Script Date: 6/5/2025 8:08:01 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[THE_USERS](
	[THE_USER] [varchar](50) NOT NULL,
	[THE_PSW] [varchar](255) NOT NULL,
	[NAME] [varchar](60) NULL,
	[LASTNAME] [varchar](60) NULL,
 CONSTRAINT [PK_THE_USERS] PRIMARY KEY CLUSTERED 
(
	[THE_USER] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_THE_CLIENT_CRUD_ACTION]

-- %%
ALTER TABLE [dbo].[THE_CLIENT] ADD  CONSTRAINT [DF_THE_CLIENT_CRUD_ACTION]  DEFAULT ('CREATE') FOR [CRUD_ACTION]
GO

-- %% [markdown]
-- # [FK_LOG_CLIE_REF_THE_CLIE]

-- %%
ALTER TABLE [dbo].[LOG_CLIENT]  WITH CHECK ADD  CONSTRAINT [FK_LOG_CLIE_REF_THE_CLIE] FOREIGN KEY([ID_CLIENT])
REFERENCES [dbo].[THE_CLIENT] ([ID_CLIENT])
GO
ALTER TABLE [dbo].[LOG_CLIENT] CHECK CONSTRAINT [FK_LOG_CLIE_REF_THE_CLIE]
GO

-- %% [markdown]
-- # [FK_LOG_CLIE_REF_THE_USER]

-- %%
ALTER TABLE [dbo].[LOG_CLIENT]  WITH CHECK ADD  CONSTRAINT [FK_LOG_CLIE_REF_THE_USER] FOREIGN KEY([THE_USER])
REFERENCES [dbo].[THE_USERS] ([THE_USER])
GO
ALTER TABLE [dbo].[LOG_CLIENT] CHECK CONSTRAINT [FK_LOG_CLIE_REF_THE_USER]
GO

-- %% [markdown]
-- # [FK_THE_CLIE_REF_THE_USER]

-- %%
ALTER TABLE [dbo].[THE_CLIENT]  WITH CHECK ADD  CONSTRAINT [FK_THE_CLIE_REF_THE_USER] FOREIGN KEY([USR_CRUD_ACTION])
REFERENCES [dbo].[THE_USERS] ([THE_USER])
GO
ALTER TABLE [dbo].[THE_CLIENT] CHECK CONSTRAINT [FK_THE_CLIE_REF_THE_USER]
GO
